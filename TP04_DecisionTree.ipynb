# %% [markdown]
# # Les arbres de decision
# ## Objectif
#
# 1.  Comprendre l'algorithme des Arbres de décision
# 2.  Comprendre la mésure de selection d'attributs:
# > *   Information Gain
# > *   Gain Ratio
# > *   Gini index
# 3.  Créer un arbre de decision en utilisant Scikit-learn
# 4.  Utilisation des differentes metriques pour l'évaluation d'un modèle
# 4.  Optimiser les performance d'un arbre de decision
#
# ## Introduction
# Un arbre de décision est une structure arborescente semblable à un organigramme où un **nœud interne** représente une caractéristique (ou un attribut), la branche représente une règle de décision et chaque **nœud feuille** représente le résultat. Le nœud le plus élevé dans un arbre de décision est connu sous le nom de **nœud racine**.
#
# Un arbre de décision est facile à comprendre et à interpréter car il apprend à partitionner sur la base de la valeur d'attribut. Il partitionne l'arborescence de manière récursive en appelant le partitionnement récursif. Cette structure de type organigramme vous aide à prendre des décisions. C'est une visualisation comme un diagramme d'organigramme qui imite facilement la pensée au niveau humain. C'est pourquoi les arbres de décision sont faciles à comprendre et à interpréter.
# ![image-2.png](attachment:image-2.png)
#
# ## Algorithme
# 1.  Sélectionnez le meilleur attribut à l'aide des mesures de sélection d'attribut (ASM) pour fractionner les enregistrements.
# 2. Faire de cet attribut le nœud de décision et divisez l'ensemble de données en sous-ensembles plus petits.
# 3. Répéter ce processus de manière récursive pour chaque nœud enfant jusqu'à ce que l'une des conditions corresponde:
# >- Tous les tuples appartiennent à la même valeur d'attribut.
# >- Il n'y a plus d'attributs restants.
# >- Il n'y a plus d'instances.
#
# ![image-4.png](attachment:image-4.png)
#
# ## Mesures de sélection d'attribut
# La mesure de sélection d'attribut (Atribut Selection Mesure ASM) permet de sélectionner le critère de fractionnement qui partitionne les données de la meilleure manière possible. L'attribut avec le meilleur ASM sera sélectionné comme attribut de division. Dans le cas d'un attribut à valeur continue, les points de partage des branches doivent également être définis. Les mesures de sélection les plus populaires sont:
# >- le gain d'information(**Information Gain**)
# >- le ratio de gain (**Gain Ratio**)
# >- l'indice de Gini(**Gini Index**).
#
# ## Réferences:
# https://www.analyticssteps.com/blogs/decision-tree-machine-learning

# %% [markdown]
# ## Q1. Chargement des données
# 1- Construire un Dataframe ***data*** contenant les données stoker dans le fichier ***diabetes.csv***  https://www.kaggle.com/uciml/pima-indians-diabetes-database
#
# 2- visualiser ce dataframe ainsi que les diferentes mesure sur ce dataframe

# %%
#1
import pandas as pd
df = pd.read_csv("diabetes.csv")

# %%
#2
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# ## Q2. Selection des caracteristiques
# Créer les deux dataframes:
# - X: le dataframe des entrée
# - y: la sortie (outcome)

# %%
X = df[["Pregnancies","Glucose","BloodPressure","SkinThickness","Insulin","BMI","DiabetesPedigreeFunction","Age"]]
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
y = df["Outcome"]
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# ## Q3. Partitionner ces données en X_train, X_test, y_train, y_test

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, train_size=0.8)

# %% [markdown]
# ## Q4. Création, entrainement et évaluation du modèle
# 1. Utiliser le classifieur ***DecisionTreeClassifier*** du module ***sklearn.tree*** pour initialiser et entrainer un arbre de décision
# 2. Afficher la matrice de confusion de ce modèle
# 3. Calculer les trois metrics suivante:
# >- Accuracy
# >- Prcison
# >- recall
# >- F1 score
#
# de ce modèle (voir l'article suivant: https://towardsdatascience.com/accuracy-precision-recall-or-f1-331fb37c5cb9)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

#1
Tree = DecisionTreeClassifier()
Tree.fit(X_train,y_train)

#2
y_pred = Tree.predict(X_test)
matrix = confusion_matrix(y_test, y_pred)
matrix
# Out:
# array([[89, 21],
#        [17, 27]], dtype=int64)

# %%
#3
TN,FP,FN,TP = matrix.ravel()

Accuracy = (TP+TN)/(TP+TN+FN+FP)
Recall = TP/TP+FN
Precision = TP/TP+FP
F1_score = (2*Precision*Recall)/(Precision+Recall)

print("L'exactitude: ",Accuracy)
print("Le recall: ",Recall)
print("La precision: ",Precision)
print("Le F1_score: ",F1_score)
# Out:
# L'exactitude:  0.7532467532467533
# Le recall:  18.0
# La precision:  22.0
# Le F1_score:  19.8

# %% [markdown]
# ## Q5. Visualisation d'un arbre de décision
# 1. Utiliser la fonction ***plot_tree(dt)***  de ***sklearn.tree*** pour visualiser l'arbre de décision résultante
# 2. Que remarqez-vous?

# %%
#1

from sklearn.tree import plot_tree
plt.figure(figsize = (30,30))
plot_tree(Tree, filled=True, fontsize= 20, feature_names= df.columns[:], class_names=['0','1'])

#2
# Out:
# [Text(1042.1672350888325, 1582.835294117647, 'Glucose <= 154.5\ngini = 0.463\nsamples = 614\nvalue = [390, 224]\nclass = 0'),
#  Text(520.8014752538071, 1486.9058823529413, 'Age <= 28.5\ngini = 0.397\nsamples = 513\nvalue = [373, 140]\nclass = 0'),
#  Text(302.7220812182741, 1390.9764705882353, 'Glucose <= 130.5\ngini = 0.232\nsamples = 261\nvalue = [226, 35]\nclass = 0'),
#  Text(172.0736040609137, 1295.0470588235294, 'BMI <= 45.4\ngini = 0.163\nsamples = 224\nvalue = [204, 20]\nclass = 0'),
#  Text(155.07868020304568, 1199.1176470588234, 'BMI <= 30.95\ngini = 0.149\nsamples = 222\nvalue = [204, 18]\nclass = 0'),
#  Text(84.9746192893401, 1103.1882352941175, 'Pregnancies <= 7.5\ngini = 0.047\nsamples = 124\nvalue = [121, 3]\nclass = 0'),
#  Text(67.97969543147208, 1007.2588235294118, 'Age <= 27.5\ngini = 0.032\nsamples = 123\nvalue = [121, 2]\nclass = 0'),
#  Text(33.98984771573604, 911.3294117647059, 'DiabetesPedigreeFunction <= 0.672\ngini = 0.017\nsamples = 117\nvalue = [116, 1]\nclass = 0'),
#  Text(16.99492385786802, 815.4, 'gini = 0.0\nsamples = 103\nvalue = [103, 0]\nclass = 0'),
#  Text(50.984771573604064, 815.4, 'DiabetesPedigreeFunction <= 0.685\ngini = 0.133\nsamples = 14\nvalue = [13, 1]\nclass = 0'),
#  Text(33.98984771573604, 719.4705882352941, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(67.97969543147208, 719.4705882352941, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = 0'),
#  Text(101.96954314720813, 911.3294117647059, 'SkinThickness <= 24.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = 0'),
#  Text(84.9746192893401, 815.4, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(118.96446700507614, 815.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(101.96954314720813, 1007.2588235294118, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(225.18274111675126, 1103.1882352941175, 'BloodPressure <= 54.0\ngini = 0.259\nsamples = 98\nvalue = [83, 15]\nclass = 0'),
#  Text(152.9543147208122, 1007.2588235294118, 'DiabetesPedigreeFunction <= 0.264\ngini = 0.5\nsamples = 10\nvalue = [5, 5]\nclass = 0'),
#  Text(135.95939086294416, 911.3294117647059, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(169.9492385786802, 911.3294117647059, 'Insulin <= 166.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = 0'),
#  Text(152.9543147208122, 815.4, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(186.94416243654823, 815.4, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(297.4111675126903, 1007.2588235294118, 'DiabetesPedigreeFunction <= 0.662\ngini = 0.201\nsamples = 88\nvalue = [78, 10]\nclass = 0'),
#  Text(237.9289340101523, 911.3294117647059, 'Insulin <= 36.5\ngini = 0.112\nsamples = 67\nvalue = [63, 4]\nclass = 0'),
#  Text(220.93401015228426, 815.4, 'BloodPressure <= 73.0\ngini = 0.278\nsamples = 24\nvalue = [20, 4]\nclass = 0'),
#  Text(203.93908629441626, 719.4705882352941, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = 0'),
#  Text(237.9289340101523, 719.4705882352941, 'Glucose <= 112.5\ngini = 0.463\nsamples = 11\nvalue = [7, 4]\nclass = 0'),
#  Text(220.93401015228426, 623.5411764705883, 'Insulin <= 34.0\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = 0'),
#  Text(203.93908629441626, 527.6117647058825, 'BloodPressure <= 74.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = 0'),
#  Text(186.94416243654823, 431.68235294117653, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(220.93401015228426, 431.68235294117653, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = 0'),
#  Text(237.9289340101523, 527.6117647058825, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(254.9238578680203, 623.5411764705883, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(254.9238578680203, 815.4, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]\nclass = 0'),
#  Text(356.89340101522845, 911.3294117647059, 'Insulin <= 63.5\ngini = 0.408\nsamples = 21\nvalue = [15, 6]\nclass = 0'),
#  Text(322.9035532994924, 815.4, 'Age <= 22.0\ngini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = 0'),
#  Text(305.9086294416244, 719.4705882352941, 'SkinThickness <= 8.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(288.9137055837563, 623.5411764705883, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(322.9035532994924, 623.5411764705883, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(339.8984771573604, 719.4705882352941, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = 0'),
#  Text(390.88324873096445, 815.4, 'Glucose <= 109.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]\nclass = 0'),
#  Text(373.88832487309645, 719.4705882352941, 'BMI <= 32.25\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = 1'),
#  Text(356.89340101522845, 623.5411764705883, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(390.88324873096445, 623.5411764705883, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1'),
#  Text(407.8781725888325, 719.4705882352941, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(189.0685279187817, 1199.1176470588234, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(433.3705583756345, 1295.0470588235294, 'BloodPressure <= 29.0\ngini = 0.482\nsamples = 37\nvalue = [22, 15]\nclass = 0'),
#  Text(416.3756345177665, 1199.1176470588234, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1'),
#  Text(450.3654822335025, 1199.1176470588234, 'BMI <= 27.65\ngini = 0.43\nsamples = 32\nvalue = [22, 10]\nclass = 0'),
#  Text(433.3705583756345, 1103.1882352941175, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = 0'),
#  Text(467.3604060913706, 1103.1882352941175, 'DiabetesPedigreeFunction <= 0.309\ngini = 0.486\nsamples = 24\nvalue = [14, 10]\nclass = 0'),
#  Text(424.8730964467005, 1007.2588235294118, 'SkinThickness <= 39.0\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = 0'),
#  Text(407.8781725888325, 911.3294117647059, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0'),
#  Text(441.8680203045685, 911.3294117647059, 'Age <= 24.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(424.8730964467005, 815.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(458.8629441624365, 815.4, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(509.8477157360406, 1007.2588235294118, 'DiabetesPedigreeFunction <= 0.373\ngini = 0.492\nsamples = 16\nvalue = [7, 9]\nclass = 1'),
#  Text(492.8527918781726, 911.3294117647059, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(526.8426395939086, 911.3294117647059, 'Glucose <= 142.5\ngini = 0.486\nsamples = 12\nvalue = [7, 5]\nclass = 0'),
#  Text(492.8527918781726, 815.4, 'Glucose <= 133.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = 1'),
#  Text(475.8578680203046, 719.4705882352941, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(509.8477157360406, 719.4705882352941, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(560.8324873096446, 815.4, 'BloodPressure <= 60.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = 0'),
#  Text(543.8375634517766, 719.4705882352941, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(577.8274111675127, 719.4705882352941, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0'),
#  Text(738.8808692893401, 1390.9764705882353, 'BMI <= 26.35\ngini = 0.486\nsamples = 252\nvalue = [147, 105]\nclass = 0'),
#  Text(577.8274111675127, 1295.0470588235294, 'BMI <= 9.65\ngini = 0.145\nsamples = 38\nvalue = [35, 3]\nclass = 0'),
#  Text(543.8375634517766, 1199.1176470588234, 'DiabetesPedigreeFunction <= 0.45\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(526.8426395939086, 1103.1882352941175, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(560.8324873096446, 1103.1882352941175, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(611.8172588832488, 1199.1176470588234, 'Age <= 59.0\ngini = 0.056\nsamples = 35\nvalue = [34, 1]\nclass = 0'),
#  Text(594.8223350253807, 1103.1882352941175, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]\nclass = 0'),
#  Text(628.8121827411168, 1103.1882352941175, 'DiabetesPedigreeFunction <= 0.343\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = 0'),
#  Text(611.8172588832488, 1007.2588235294118, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(645.8071065989848, 1007.2588235294118, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(899.9343274111675, 1295.0470588235294, 'Glucose <= 99.5\ngini = 0.499\nsamples = 214\nvalue = [112, 102]\nclass = 0'),
#  Text(696.7918781725888, 1199.1176470588234, 'Glucose <= 30.5\ngini = 0.346\nsamples = 45\nvalue = [35, 10]\nclass = 0'),
#  Text(679.7969543147208, 1103.1882352941175, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(713.7868020304569, 1103.1882352941175, 'Insulin <= 87.0\ngini = 0.303\nsamples = 43\nvalue = [35, 8]\nclass = 0'),
#  Text(679.7969543147208, 1007.2588235294118, 'DiabetesPedigreeFunction <= 1.16\ngini = 0.224\nsamples = 39\nvalue = [34, 5]\nclass = 0'),
#  Text(662.8020304568528, 911.3294117647059, 'Age <= 44.5\ngini = 0.188\nsamples = 38\nvalue = [34, 4]\nclass = 0'),
#  Text(628.8121827411168, 815.4, 'DiabetesPedigreeFunction <= 0.171\ngini = 0.064\nsamples = 30\nvalue = [29, 1]\nclass = 0'),
#  Text(611.8172588832488, 719.4705882352941, 'SkinThickness <= 19.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(594.8223350253807, 623.5411764705883, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(628.8121827411168, 623.5411764705883, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(645.8071065989848, 719.4705882352941, 'gini = 0.0\nsamples = 27\nvalue = [27, 0]\nclass = 0'),
#  Text(696.7918781725888, 815.4, 'SkinThickness <= 25.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = 0'),
#  Text(679.7969543147208, 719.4705882352941, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(713.7868020304569, 719.4705882352941, 'DiabetesPedigreeFunction <= 0.27\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = 1'),
#  Text(696.7918781725888, 623.5411764705883, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(730.7817258883249, 623.5411764705883, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(696.7918781725888, 911.3294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(747.7766497461929, 1007.2588235294118, 'DiabetesPedigreeFunction <= 0.159\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = 1'),
#  Text(730.7817258883249, 911.3294117647059, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(764.7715736040609, 911.3294117647059, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(1103.076776649746, 1199.1176470588234, 'DiabetesPedigreeFunction <= 0.201\ngini = 0.496\nsamples = 169\nvalue = [77, 92]\nclass = 1'),
#  Text(849.746192893401, 1103.1882352941175, 'Glucose <= 134.0\ngini = 0.417\nsamples = 27\nvalue = [19, 8]\nclass = 0'),
#  Text(815.756345177665, 1007.2588235294118, 'Pregnancies <= 5.5\ngini = 0.266\nsamples = 19\nvalue = [16, 3]\nclass = 0'),
#  Text(798.7614213197969, 911.3294117647059, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = 0'),
#  Text(832.751269035533, 911.3294117647059, 'BMI <= 34.55\ngini = 0.42\nsamples = 10\nvalue = [7, 3]\nclass = 0'),
#  Text(815.756345177665, 815.4, 'Age <= 38.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = 1'),
#  Text(798.7614213197969, 719.4705882352941, 'Glucose <= 103.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(781.7664974619289, 623.5411764705883, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(815.756345177665, 623.5411764705883, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(832.751269035533, 719.4705882352941, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(849.746192893401, 815.4, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(883.736040609137, 1007.2588235294118, 'DiabetesPedigreeFunction <= 0.159\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = 1'),
#  Text(866.741116751269, 911.3294117647059, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(900.730964467005, 911.3294117647059, 'BMI <= 30.2\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(883.736040609137, 815.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(917.725888324873, 815.4, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(1356.4073604060914, 1103.1882352941175, 'BMI <= 43.0\ngini = 0.483\nsamples = 142\nvalue = [58, 84]\nclass = 1'),
#  Text(1276.743654822335, 1007.2588235294118, 'Age <= 61.5\ngini = 0.493\nsamples = 129\nvalue = [57, 72]\nclass = 1'),
#  Text(1168.4010152284263, 911.3294117647059, 'Age <= 42.5\ngini = 0.488\nsamples = 123\nvalue = [52, 71]\nclass = 1'),
#  Text(1002.7005076142132, 815.4, 'Glucose <= 119.5\ngini = 0.5\nsamples = 82\nvalue = [41, 41]\nclass = 0'),
#  Text(913.4771573604061, 719.4705882352941, 'Pregnancies <= 6.5\ngini = 0.451\nsamples = 32\nvalue = [11, 21]\nclass = 1'),
#  Text(849.746192893401, 623.5411764705883, 'Insulin <= 132.0\ngini = 0.5\nsamples = 20\nvalue = [10, 10]\nclass = 0'),
#  Text(807.258883248731, 527.6117647058825, 'BloodPressure <= 76.0\ngini = 0.48\nsamples = 15\nvalue = [9, 6]\nclass = 0'),
#  Text(773.269035532995, 431.68235294117653, 'Glucose <= 111.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = 1'),
#  Text(756.2741116751268, 335.7529411764706, 'Age <= 38.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(739.2791878172588, 239.82352941176487, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(773.269035532995, 239.82352941176487, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(790.263959390863, 335.7529411764706, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(841.248730964467, 431.68235294117653, 'Pregnancies <= 1.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = 0'),
#  Text(824.253807106599, 335.7529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(858.243654822335, 335.7529411764706, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = 0'),
#  Text(892.2335025380711, 527.6117647058825, 'Glucose <= 102.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = 1'),
#  Text(875.2385786802031, 431.68235294117653, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(909.2284263959391, 431.68235294117653, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = 1'),
#  Text(977.2081218274111, 623.5411764705883, 'BloodPressure <= 56.0\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = 1'),
#  Text(960.2131979695431, 527.6117647058825, 'Age <= 37.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(943.2182741116751, 431.68235294117653, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(977.2081218274111, 431.68235294117653, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(994.2030456852792, 527.6117647058825, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = 1'),
#  Text(1091.9238578680204, 719.4705882352941, 'DiabetesPedigreeFunction <= 0.235\ngini = 0.48\nsamples = 50\nvalue = [30, 20]\nclass = 0'),
#  Text(1045.1878172588833, 623.5411764705883, 'BloodPressure <= 75.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = 1'),
#  Text(1028.1928934010152, 527.6117647058825, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1'),
#  Text(1062.1827411167512, 527.6117647058825, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(1138.6598984771574, 623.5411764705883, 'DiabetesPedigreeFunction <= 0.737\ngini = 0.449\nsamples = 44\nvalue = [29, 15]\nclass = 0'),
#  Text(1096.1725888324872, 527.6117647058825, 'SkinThickness <= 28.5\ngini = 0.36\nsamples = 34\nvalue = [26, 8]\nclass = 0'),
#  Text(1062.1827411167512, 431.68235294117653, 'Pregnancies <= 3.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]\nclass = 0'),
#  Text(1045.1878172588833, 335.7529411764706, 'Pregnancies <= 2.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(1028.1928934010152, 239.82352941176487, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(1062.1827411167512, 239.82352941176487, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(1079.1776649746193, 335.7529411764706, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = 0'),
#  Text(1130.1624365482232, 431.68235294117653, 'BMI <= 29.5\ngini = 0.492\nsamples = 16\nvalue = [9, 7]\nclass = 0'),
#  Text(1113.1675126903554, 335.7529411764706, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(1147.1573604060914, 335.7529411764706, 'BMI <= 34.85\ngini = 0.426\nsamples = 13\nvalue = [9, 4]\nclass = 0'),
#  Text(1130.1624365482232, 239.82352941176487, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(1164.1522842639595, 239.82352941176487, 'DiabetesPedigreeFunction <= 0.484\ngini = 0.5\nsamples = 8\nvalue = [4, 4]\nclass = 0'),
#  Text(1147.1573604060914, 143.89411764705892, 'SkinThickness <= 38.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = 0'),
#  Text(1130.1624365482232, 47.96470588235297, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(1164.1522842639595, 47.96470588235297, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(1181.1472081218274, 143.89411764705892, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(1181.1472081218274, 527.6117647058825, 'Age <= 38.5\ngini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = 1'),
#  Text(1164.1522842639595, 431.68235294117653, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = 1'),
#  Text(1198.1421319796955, 431.68235294117653, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(1334.1015228426395, 815.4, 'DiabetesPedigreeFunction <= 1.415\ngini = 0.393\nsamples = 41\nvalue = [11, 30]\nclass = 1'),
#  Text(1317.1065989847716, 719.4705882352941, 'Glucose <= 127.5\ngini = 0.355\nsamples = 39\nvalue = [9, 30]\nclass = 1'),
#  Text(1283.1167512690356, 623.5411764705883, 'BloodPressure <= 83.0\ngini = 0.463\nsamples = 22\nvalue = [8, 14]\nclass = 1'),
#  Text(1266.1218274111675, 527.6117647058825, 'Age <= 53.5\ngini = 0.346\nsamples = 18\nvalue = [4, 14]\nclass = 1'),
#  Text(1232.1319796954315, 431.68235294117653, 'BloodPressure <= 30.0\ngini = 0.231\nsamples = 15\nvalue = [2, 13]\nclass = 1'),
#  Text(1215.1370558375634, 335.7529411764706, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(1249.1269035532994, 335.7529411764706, 'Pregnancies <= 9.5\ngini = 0.133\nsamples = 14\nvalue = [1, 13]\nclass = 1'),
#  Text(1232.1319796954315, 239.82352941176487, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = 1'),
#  Text(1266.1218274111675, 239.82352941176487, 'BMI <= 32.1\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(1249.1269035532994, 143.89411764705892, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(1283.1167512690356, 143.89411764705892, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(1300.1116751269035, 431.68235294117653, 'DiabetesPedigreeFunction <= 0.968\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(1283.1167512690356, 335.7529411764706, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(1317.1065989847716, 335.7529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(1300.1116751269035, 527.6117647058825, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = 0'),
#  Text(1351.0964467005076, 623.5411764705883, 'DiabetesPedigreeFunction <= 0.222\ngini = 0.111\nsamples = 17\nvalue = [1, 16]\nclass = 1'),
#  Text(1334.1015228426395, 527.6117647058825, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(1368.0913705583757, 527.6117647058825, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]\nclass = 1'),
#  Text(1351.0964467005076, 719.4705882352941, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(1385.0862944162436, 911.3294117647059, 'Age <= 68.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = 0'),
#  Text(1368.0913705583757, 815.4, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(1402.0812182741117, 815.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(1436.0710659898477, 1007.2588235294118, 'Glucose <= 100.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]\nclass = 1'),
#  Text(1419.0761421319796, 911.3294117647059, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(1453.0659898477156, 911.3294117647059, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = 1'),
#  Text(1563.5329949238578, 1486.9058823529413, 'BMI <= 23.15\ngini = 0.28\nsamples = 101\nvalue = [17, 84]\nclass = 1'),
#  Text(1546.53807106599, 1390.9764705882353, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(1580.527918781726, 1390.9764705882353, 'Age <= 66.5\ngini = 0.257\nsamples = 99\nvalue = [15, 84]\nclass = 1'),
#  Text(1563.5329949238578, 1295.0470588235294, 'DiabetesPedigreeFunction <= 0.126\ngini = 0.245\nsamples = 98\nvalue = [14, 84]\nclass = 1'),
#  Text(1546.53807106599, 1199.1176470588234, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(1580.527918781726, 1199.1176470588234, 'BloodPressure <= 93.0\ngini = 0.232\nsamples = 97\nvalue = [13, 84]\nclass = 1'),
#  Text(1538.0406091370558, 1103.1882352941175, 'BMI <= 46.1\ngini = 0.198\nsamples = 90\nvalue = [10, 80]\nclass = 1'),
#  Text(1504.0507614213197, 1007.2588235294118, 'BMI <= 34.05\ngini = 0.156\nsamples = 82\nvalue = [7, 75]\nclass = 1'),
#  Text(1487.0558375634519, 911.3294117647059, 'Age <= 26.5\ngini = 0.278\nsamples = 42\nvalue = [7, 35]\nclass = 1'),
#  Text(1436.0710659898477, 815.4, 'BloodPressure <= 68.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = 0'),
#  Text(1419.0761421319796, 719.4705882352941, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(1453.0659898477156, 719.4705882352941, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(1538.0406091370558, 815.4, 'SkinThickness <= 42.5\ngini = 0.193\nsamples = 37\nvalue = [4, 33]\nclass = 1'),
#  Text(1487.0558375634519, 719.4705882352941, 'Age <= 48.0\ngini = 0.157\nsamples = 35\nvalue = [3, 32]\nclass = 1'),
#  Text(1436.0710659898477, 623.5411764705883, 'Glucose <= 190.0\ngini = 0.08\nsamples = 24\nvalue = [1, 23]\nclass = 1'),
#  Text(1419.0761421319796, 527.6117647058825, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]\nclass = 1'),
#  Text(1453.0659898477156, 527.6117647058825, 'BloodPressure <= 69.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = 1'),
#  Text(1436.0710659898477, 431.68235294117653, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(1470.0609137055837, 431.68235294117653, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(1538.0406091370558, 623.5411764705883, 'Glucose <= 165.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]\nclass = 1'),
#  Text(1521.0456852791879, 527.6117647058825, 'Glucose <= 159.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = 1'),
#  Text(1504.0507614213197, 431.68235294117653, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = 1'),
#  Text(1538.0406091370558, 431.68235294117653, 'BloodPressure <= 86.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(1521.0456852791879, 335.7529411764706, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(1555.0355329949239, 335.7529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(1555.0355329949239, 527.6117647058825, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = 1'),
#  Text(1589.0253807106599, 719.4705882352941, 'SkinThickness <= 44.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = 0'),
#  Text(1572.0304568527918, 623.5411764705883, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(1606.020304568528, 623.5411764705883, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(1521.0456852791879, 911.3294117647059, 'gini = 0.0\nsamples = 40\nvalue = [0, 40]\nclass = 1'),
#  Text(1572.0304568527918, 1007.2588235294118, 'Insulin <= 177.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = 1'),
#  Text(1555.0355329949239, 911.3294117647059, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = 1'),
#  Text(1589.0253807106599, 911.3294117647059, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(1623.0152284263959, 1103.1882352941175, 'Glucose <= 173.0\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = 1'),
#  Text(1606.020304568528, 1007.2588235294118, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = 1'),
#  Text(1640.010152284264, 1007.2588235294118, 'Pregnancies <= 2.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = 0'),
#  Text(1623.0152284263959, 911.3294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = 1'),
#  Text(1657.0050761421319, 911.3294117647059, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(1597.5228426395938, 1295.0470588235294, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0')]

# %% [markdown]
# ## Q6. Optimisation les performance d'un arbre de décision
# 1. Créer deux arbres de décisions avec les paramétres suivants:
# >- Arbre 1: ( ASM = entropy , max_depth: 3)
# >- Arbre 2: ( ASM = gini , max_depth: 3)
#
# > NB: utiliser la documentation https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
#
# 2. Comparer les resultats avec celles de la question Q5

# %%
#1

Arbre1 = DecisionTreeClassifier(criterion = "entropy" , max_depth= 3)
Arbre1.fit(X_train,y_train)

Arbre2 = DecisionTreeClassifier(criterion = "gini" , max_depth= 3)
Arbre2.fit(X_train,y_train)

#2
plt.figure(figsize = (30,30))
plot_tree(Arbre1, filled=True, fontsize=20, feature_names= df.columns[:], class_names=['0','1'])
# Out:
# [Text(837.0, 1426.95, 'Glucose <= 154.5\nentropy = 0.947\nsamples = 614\nvalue = [390, 224]\nclass = 0'),
#  Text(418.5, 1019.25, 'BMI <= 26.35\nentropy = 0.846\nsamples = 513\nvalue = [373, 140]\nclass = 0'),
#  Text(209.25, 611.55, 'Pregnancies <= 2.5\nentropy = 0.212\nsamples = 119\nvalue = [115, 4]\nclass = 0'),
#  Text(104.625, 203.8499999999999, 'entropy = 0.0\nsamples = 65\nvalue = [65, 0]\nclass = 0'),
#  Text(313.875, 203.8499999999999, 'entropy = 0.381\nsamples = 54\nvalue = [50, 4]\nclass = 0'),
#  Text(627.75, 611.55, 'Age <= 30.5\nentropy = 0.93\nsamples = 394\nvalue = [258, 136]\nclass = 0'),
#  Text(523.125, 203.8499999999999, 'entropy = 0.735\nsamples = 208\nvalue = [165, 43]\nclass = 0'),
#  Text(732.375, 203.8499999999999, 'entropy = 1.0\nsamples = 186\nvalue = [93, 93]\nclass = 0'),
#  Text(1255.5, 1019.25, 'BMI <= 29.1\nentropy = 0.654\nsamples = 101\nvalue = [17, 84]\nclass = 1'),
#  Text(1046.25, 611.55, 'Age <= 25.5\nentropy = 0.989\nsamples = 16\nvalue = [7, 9]\nclass = 1'),
#  Text(941.625, 203.8499999999999, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = 0'),
#  Text(1150.875, 203.8499999999999, 'entropy = 0.89\nsamples = 13\nvalue = [4, 9]\nclass = 1'),
#  Text(1464.75, 611.55, 'Pregnancies <= 7.5\nentropy = 0.523\nsamples = 85\nvalue = [10, 75]\nclass = 1'),
#  Text(1360.125, 203.8499999999999, 'entropy = 0.592\nsamples = 70\nvalue = [10, 60]\nclass = 1'),
#  Text(1569.375, 203.8499999999999, 'entropy = 0.0\nsamples = 15\nvalue = [0, 15]\nclass = 1')]

# %%
plt.figure(figsize = (30,30))
plot_tree(Arbre2, filled=True, fontsize=20, feature_names= df.columns[:], class_names=['0','1'])

#On remarque
# Out:
# [Text(906.75, 1426.95, 'Glucose <= 154.5\ngini = 0.463\nsamples = 614\nvalue = [390, 224]\nclass = 0'),
#  Text(558.0, 1019.25, 'Age <= 28.5\ngini = 0.397\nsamples = 513\nvalue = [373, 140]\nclass = 0'),
#  Text(279.0, 611.55, 'Glucose <= 130.5\ngini = 0.232\nsamples = 261\nvalue = [226, 35]\nclass = 0'),
#  Text(139.5, 203.8499999999999, 'gini = 0.163\nsamples = 224\nvalue = [204, 20]\nclass = 0'),
#  Text(418.5, 203.8499999999999, 'gini = 0.482\nsamples = 37\nvalue = [22, 15]\nclass = 0'),
#  Text(837.0, 611.55, 'BMI <= 26.35\ngini = 0.486\nsamples = 252\nvalue = [147, 105]\nclass = 0'),
#  Text(697.5, 203.8499999999999, 'gini = 0.145\nsamples = 38\nvalue = [35, 3]\nclass = 0'),
#  Text(976.5, 203.8499999999999, 'gini = 0.499\nsamples = 214\nvalue = [112, 102]\nclass = 0'),
#  Text(1255.5, 1019.25, 'BMI <= 23.15\ngini = 0.28\nsamples = 101\nvalue = [17, 84]\nclass = 1'),
#  Text(1116.0, 611.55, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = 0'),
#  Text(1395.0, 611.55, 'Age <= 66.5\ngini = 0.257\nsamples = 99\nvalue = [15, 84]\nclass = 1'),
#  Text(1255.5, 203.8499999999999, 'gini = 0.245\nsamples = 98\nvalue = [14, 84]\nclass = 1'),
#  Text(1534.5, 203.8499999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0')]

# %% [markdown]
# ## Q7. peut-on réduire le nombre de caractèristiques utilisé dans ce modèle pour obtenir les même performances?

# %% [markdown]
# ## Q8. utilisation du modèle
# Mr Rachid a fait un bilon et a obtenu les resu Après un bilon Mr
# - Age: 22
# - Glucose: 79
# - BloodPressure: 69
# - Insulin: 31
# - BMI: 0.4
#
# Mr Rachid a-t-il un diabéte?

# %%
data = pd.DataFrame({"Age":22, "Glucose":79, "BloodPressure":69, "Insulin":31, "BMI":0.4})
data
# Out:
#   File "<ipython-input-64-7d5bdfe61741>", line 1
#     data = pd.DataFrame{"Age":22, "Glucose":79, "BloodPressure":69, "Insulin":31, "BMI":0.4}
#                        ^
# SyntaxError: invalid syntax
